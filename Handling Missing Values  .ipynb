# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
import warnings     #To ignore warnings
warnings.filterwarnings("ignore")
df=pd.read_csv("/Users/manaschakraborty/Downloads/clv_data.csv")
df.head(40)
# Out:
#     Unnamed: 0  id   age  gender  income  days_on_platform           city  \
# 0            0   0   NaN    Male  126895              14.0  San Francisco
# 1            1   1   NaN    Male  161474              14.0          Tokyo
# 2            2   2  24.0    Male  104723              34.0         London
# 3            3   3  29.0    Male   43791              28.0         London
# 4            4   4  18.0  Female  132181              26.0         London
# 5            5   5  23.0    Male   12315              14.0  New York City
# 6            6   6   NaN    Male   51679              30.0          Tokyo
# 7            7   7   NaN  Female   53341              43.0  San Francisco
# 8            8   8  46.0    Male  129157              23.0  New York City
# 9            9   9  49.0  Female   76842              19.0          Tokyo
# 10          10  10   NaN    Male  159506               7.0  New York City
# 11          11  11   NaN    Male  110343              30.0  San Francisco
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        5000 non-null   int64
#  1   id                5000 non-null   int64
#  2   age               2554 non-null   float64
#  3   gender            5000 non-null   object
#  4   income            5000 non-null   int64
#  5   days_on_platform  4859 non-null   float64
#  6   city              5000 non-null   object
#  7   purchases         5000 non-null   int64
# dtypes: float64(2), int64(4), object(2)
# memory usage: 312.6+ KB

# %%
# Check for missing values
print(df.isnull().sum())
# Out:
# Unnamed: 0             0
# id                     0
# age                 2446
# gender                 0
# income                 0
# days_on_platform     141
# city                   0
# purchases              0
# dtype: int64

# %%
# Fill missing age with mean
df['age'].fillna(df['age'].mean(), inplace=True)
df['days_on_platform'].fillna(df['days_on_platform'].mean(), inplace=True)

# %%
df.head(40)
# Out:
#     Unnamed: 0  id        age  gender  income  days_on_platform  \
# 0            0   0  30.202036    Male  126895         14.000000
# 1            1   1  30.202036    Male  161474         14.000000
# 2            2   2  24.000000    Male  104723         34.000000
# 3            3   3  29.000000    Male   43791         28.000000
# 4            4   4  18.000000  Female  132181         26.000000
# 5            5   5  23.000000    Male   12315         14.000000
# 6            6   6  30.202036    Male   51679         30.000000
# 7            7   7  30.202036  Female   53341         43.000000
# 8            8   8  46.000000    Male  129157         23.000000
# 9            9   9  49.000000  Female   76842         19.000000
# 10          10  10  30.202036    Male  159506          7.000000
# 11          11  11  30.202036    Male  110343         30.000000
# 12          12  12  12.000000    Male  130521         12.000000
# 13          13  13  30.202036    Male  105418         13.000000
# ...

# %%
# Now we will remove missing values

# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sb
# %matplotlib inline
import warnings     #To ignore warnings
warnings.filterwarnings("ignore")
df1=pd.read_csv("/Users/manaschakraborty/Downloads/clv_data.csv")
df1.head(40)
# Out:
#     Unnamed: 0  id   age  gender  income  days_on_platform           city  \
# 0            0   0   NaN    Male  126895              14.0  San Francisco
# 1            1   1   NaN    Male  161474              14.0          Tokyo
# 2            2   2  24.0    Male  104723              34.0         London
# 3            3   3  29.0    Male   43791              28.0         London
# 4            4   4  18.0  Female  132181              26.0         London
# 5            5   5  23.0    Male   12315              14.0  New York City
# 6            6   6   NaN    Male   51679              30.0          Tokyo
# 7            7   7   NaN  Female   53341              43.0  San Francisco
# 8            8   8  46.0    Male  129157              23.0  New York City
# 9            9   9  49.0  Female   76842              19.0          Tokyo
# 10          10  10   NaN    Male  159506               7.0  New York City
# 11          11  11   NaN    Male  110343              30.0  San Francisco
# ...

# %%
# Check for missing values
print(df1.isnull().sum())
# Out:
# Unnamed: 0             0
# id                     0
# age                 2446
# gender                 0
# income                 0
# days_on_platform     141
# city                   0
# purchases              0
# dtype: int64

# %%
# Drop rows with missing names
df1.dropna(subset=['age'], inplace=True)
df1.dropna(subset=['days_on_platform'], inplace=True)
df1.head(40)
# Out:
#     Unnamed: 0  id   age  gender  income  days_on_platform           city  \
# 2            2   2  24.0    Male  104723              34.0         London
# 3            3   3  29.0    Male   43791              28.0         London
# 4            4   4  18.0  Female  132181              26.0         London
# 5            5   5  23.0    Male   12315              14.0  New York City
# 8            8   8  46.0    Male  129157              23.0  New York City
# 9            9   9  49.0  Female   76842              19.0          Tokyo
# 12          12  12  12.0    Male  130521              12.0         London
# 15          15  15  31.0  Female  226249              20.0          Miami
# 16          16  16  19.0  Female   51434              18.0  New York City
# 17          17  17  27.0  Female  177582               2.0         London
# 18          18  18  10.0  Female     260              32.0  San Francisco
# 19          19  19  32.0  Female   15174              13.0          Tokyo
# ...

# %%
# Checking for duplicate values
duplicates = df1[df1.duplicated()]
print(duplicates)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, id, age, gender, income, days_on_platform, city, purchases]
# Index: []
